# %% [markdown]
# ####***Data Visualization is the graphic representation of Data.***

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
yeild_apples = [0.895, 0.91, 0.919, 0.926, 0.929, 0.931]

# %%
plt.plot(yeild_apples)

# %%
plt.plot(yeild_apples);   #semi colon to avoid that description line in the above cell

# %%
years = [2010, 2011, 2012, 2013, 2014, 2015]
yeild_apples = [0.895, 0.91, 0.919, 0.926, 0.929, 0.931]

# %%
plt.plot(years, yeild_apples);

# %%
plt.plot(years, yeild_apples)
plt.xlabel('Year')
plt.ylabel('Yeild (tons per hectare)')
plt.title('Crop yeild of apples in Kanto region')
# Out:
# Text(0.5, 1.0, 'Crop yeild of apples in Kanto region')

# %%
years = range(2000,2012)
apples = [0.893, 0.900, 0.902, 0.907, 0.912, 0.914, 0.917, 0.919, 0.924, 0.929, 0.933, 0.937]
oranges = [0.790, 0.804, 0.820, 0.839, 0.851, 0.868, 0.886, 0.898, 0.915, 0.933, 0.945, 0.962]
# apples = [0.893, 0.896, 0.902, 0.906, 0.913, 0.916, 0.922, 0.927, 0.931, 0.932, 0.934, 0.935, 0.936, 0.935, 0.933, 0.93, 0.927, 0.922, 0.917, 0.913, 0.908, 0.904, 0.901, 0.897, 0.894]
# oranges = [0.961, 0.957, 0.952, 0.948, 0.944, 0.939, 0.934, 0.931, 0.927,0.922, 0.918, 0.913, 0.909, 0.904, 0.899, 0.895, 0.891, 0.886,0.881, 0.877, 0.872, 0.867, 0.863, 0.858, 0.854]

# %%
plt.plot(years, apples);
plt.plot(years, oranges);
plt.xlabel('Year');
plt.ylabel('Yeild (tons per hectare)');
plt.title('Crop yeild of apples and oranges in Kanto region');
plt.legend(['Apples', 'Oranges']);

# %%
plt.plot(years, apples, marker='o');
plt.plot(years, oranges, marker='x');

plt.xlabel('Year');
plt.ylabel('Yeild (tons per hectare)');

plt.title('Crop yeild of apples and oranges in Kanto region');
plt.legend(['Apples', 'Oranges']);

# %%
plt.plot(years, apples, marker='o', c='b', ls='-', lw='2', ms=8, mew=2, mec='navy');
plt.plot(years, oranges, marker='x', c='r', ls='--', lw='3', ms=10, alpha=.5);

plt.xlabel('Year');
plt.ylabel('Yeild (tons per hectare)');

plt.title('Crop yeild of apples and oranges in Kanto region');
plt.legend(['Apples', 'Oranges']);

# %%
plt.plot(years, apples, 's-b');   # a - line s square marker and b blue colour
plt.plot(years, oranges,'o--r');    #-- line a O circular marker and  r red colour

plt.xlabel('Year');
plt.ylabel('Yeild (tons per hectare)');

plt.title('Crop yeild of apples and oranges in Kanto region');
plt.legend(['Apples', 'Oranges']);

# %%
plt.plot(years, oranges, 'or')
print('Yield of oranges (tones per hectre)')
# Out:
# Yield of oranges (tones per hectre)

# %%
plt.figure(figsize=(8,2))
plt.plot(years, oranges, 'or')
print('Yield of oranges (tones per hectre)')
# Out:
# Yield of oranges (tones per hectre)

# %% [markdown]
# ###***Improving default styles using Seaborn***

# %%
sns.set_style('whitegrid')    #you do not have to draw an imaginary line in your mind

# %%
plt.plot(years, apples, 's-b');   # a - line s square marker and b blue colour
plt.plot(years, oranges,'o--r');    #-- line a O circular marker and  r red colour

plt.xlabel('Year');
plt.ylabel('Yeild (tons per hectare)');

plt.title('Crop yeild of apples and oranges in Kanto region');
plt.legend(['Apples', 'Oranges']);

# %%
sns.set_style('darkgrid')

# %%
plt.plot(years, apples, 's-b');   # a - line s square marker and b blue colour
plt.plot(years, oranges,'o--r');    #-- line a O circular marker and  r red colour

plt.xlabel('Year');
plt.ylabel('Yeild (tons per hectare)');

plt.title('Crop yeild of apples and oranges in Kanto region');
plt.legend(['Apples', 'Oranges']);

# %%
plt.plot(years, oranges, 'or')
print('Yield of oranges (tones per hectre)')
# Out:
# Yield of oranges (tones per hectre)

# %%
import matplotlib

# %%
matplotlib.rcParams
# Out:
# RcParams({'_internal.classic_mode': False,
#           'agg.path.chunksize': 0,
#           'animation.bitrate': -1,
#           'animation.codec': 'h264',
#           'animation.convert_args': ['-layers', 'OptimizePlus'],
#           'animation.convert_path': 'convert',
#           'animation.embed_limit': 20.0,
#           'animation.ffmpeg_args': [],
#           'animation.ffmpeg_path': 'ffmpeg',
#           'animation.frame_format': 'png',
#           'animation.html': 'none',
#           'animation.writer': 'ffmpeg',
#           'axes.autolimit_mode': 'data',
#           'axes.axisbelow': True,
#           'axes.edgecolor': 'white',
#           'axes.facecolor': '#EAEAF2',
#           'axes.formatter.limits': [-5, 6],
#           'axes.formatter.min_exponent': 0,
#           'axes.formatter.offset_threshold': 4,
#           'axes.formatter.use_locale': False,
#           'axes.formatter.use_mathtext': False,
#           'axes.formatter.useoffset': True,
# ...

# %%
matplotlib.rcParams['font.size'] = 14
matplotlib.rcParams['figure.figsize'] = (9,5)
matplotlib.rcParams['figure.facecolor'] = '#00000000'

# %%
plt.plot(years, oranges, 'or')
print('Yield of oranges (tones per hectre)')
# Out:
# Yield of oranges (tones per hectre)

# %% [markdown]
# ###***Scatter Plot***

# %% [markdown]
# #####*The values of 2 variables are plotted as points on a 2 - dimensional grid*

# %%
flowers_df = sns.load_dataset('iris')

# %%
flowers_df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
flowers_df .species.unique()
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype=object)

# %%
plt.plot(flowers_df.sepal_length, flowers_df.sepal_width);

# %%
sns.scatterplot(x='sepal_length', y='sepal_width', data=flowers_df);

# %% [markdown]
# ####***Adding Hues***

# %%
sns.scatterplot(x='sepal_length', y='sepal_width', data=flowers_df, hue='species', s=100);

# %% [markdown]
# #####***Customizing Seaborn Figures***

# %%
plt.figure(figsize=(12,6))
plt.title('Scatter plot of sepal length vs sepal width')
sns.scatterplot(x='sepal_length', y='sepal_width', data=flowers_df, hue='species', s=100);

# %% [markdown]
# #####***Plotting Using Pandas Data Frames***

# %%
plt.title('Scatter plot of sepal length vs sepal width')
sns.scatterplot(x='sepal_length', y='sepal_width', data=flowers_df, hue='species', s=100);

# %% [markdown]
# #####***Histogram***

# %%
flowers_df = sns.load_dataset('iris')

# %%
flowers_df.sepal_width
# Out:
# 0      3.5
# 1      3.0
# 2      3.2
# 3      3.1
# 4      3.6
#       ...
# 145    3.0
# 146    2.5
# 147    3.0
# 148    3.4
# 149    3.0
# Name: sepal_width, Length: 150, dtype: float64

# %%
flowers_df.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
plt.title('Distribution of sepal width')
plt.hist(flowers_df.sepal_width);

# %% [markdown]
# #####***controlling the size and number of bins***

# %%
plt.hist(flowers_df.sepal_width, bins=5)        #bins are called intervals interms of histrograms
# Out:
# (array([11., 46., 68., 21.,  4.]),
#  array([2.  , 2.48, 2.96, 3.44, 3.92, 4.4 ]),
#  <BarContainer object of 5 artists>)

# %%
import numpy as np
np.arange(2,5, 0.25)      #create an array that starts at2 goes upto 5 but not five (since the last values are never included in an array) and take steps of 0.25
# Out:
# array([2.  , 2.25, 2.5 , 2.75, 3.  , 3.25, 3.5 , 3.75, 4.  , 4.25, 4.5 ,
#        4.75])

# %%
plt.hist(flowers_df.sepal_width, bins=np.arange(2,5, 0.25));

# %%
plt.hist(flowers_df.sepal_width, bins=[1,3,4,4.5]); #starting at 1 going upto 3, from 3 to 4 and so on

# %% [markdown]
# ####***Multiple Histograms***

# %%
setosa_df = flowers_df[flowers_df.species == 'setosa']
versicolor_df = flowers_df[flowers_df.species == 'versicolor']
virginica_df = flowers_df[flowers_df.species == 'virginica']

# %%
plt.hist(setosa_df.sepal_width, alpha=0.5, bins=np.arange(2,5, 0.25));
plt.hist(versicolor_df.sepal_width, alpha=0.4, bins=np.arange(2,5, 0.25));
plt.legend(['setosa', 'versicolor']);

# plt.hist(virginica_df.sepal_width, alpha=0.3, bins=np.arange(2,5, 0.25));

# %%
plt.title('Distribution of sepal width')
plt.hist([setosa_df.sepal_width, versicolor_df.sepal_width, virginica_df.sepal_width],
         bins=np.arange(2,5, 0.25),
         alpha=0.5,
         stacked=True
         );
plt.legend(['setosa', 'versicolor', 'virginica']);

# %% [markdown]
# ####Bar Chart

# %%
years = range(2000,2006)
apples = [0.35, 0.6, 0.9, 0.8, 0.65, 0.8]
oranges = [0.4, 0.8, 0.9, 0.7, 0.6, 0.8]

# %%
plt.plot(years, oranges);

# %%
plt.bar(years, oranges);

# %%
plt.bar(years, oranges);
plt.plot(years, oranges, 'o--r');

# %%
plt.bar(years, apples);
plt.bar(years, oranges, bottom=apples);

# %% [markdown]
# Bar Plots with Averages

# %%
tips_df = sns.load_dataset('tips')
tips_df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
bill_avg_df = tips_df.groupby('day')[['total_bill']].mean()
bill_avg_df
# Out:
# /tmp/ipython-input-3291797243.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   bill_avg_df = tips_df.groupby('day')[['total_bill']].mean()
#       total_bill
# day
# Thur   17.682742
# Fri    17.151579
# Sat    20.441379
# Sun    21.410000

# %%
plt.bar(bill_avg_df.index, bill_avg_df.total_bill);

# %%
sns.barplot(x='day', y='total_bill', data=tips_df);

# %%
sns.barplot(x='day', y='total_bill', data=tips_df, hue='sex');

# %%
sns.barplot(x='day', y='total_bill', data=tips_df, hue='smoker');

# %%
sns.barplot(x='total_bill', y='day', data=tips_df, hue='sex');

# %% [markdown]
# HeatMap
# #####A heatmap is used to visualize 2D data like a matrix or a table using colors

# %%
df = sns.load_dataset('flights')
df
# Out:
#      year month  passengers
# 0    1949   Jan         112
# 1    1949   Feb         118
# 2    1949   Mar         132
# 3    1949   Apr         129
# 4    1949   May         121
# ..    ...   ...         ...
# 139  1960   Aug         606
# 140  1960   Sep         508
# 141  1960   Oct         461
# 142  1960   Nov         390
# 143  1960   Dec         432
#
# [144 rows x 3 columns]

# %%
plt.plot(df.passengers);

# %%
flights_df = sns.load_dataset('flights').pivot(index='month', columns='year', values='passengers')
flights_df
# Out:
# year   1949  1950  1951  1952  1953  1954  1955  1956  1957  1958  1959  1960
# month
# Jan     112   115   145   171   196   204   242   284   315   340   360   417
# Feb     118   126   150   180   196   188   233   277   301   318   342   391
# Mar     132   141   178   193   236   235   267   317   356   362   406   419
# Apr     129   135   163   181   235   227   269   313   348   348   396   461
# May     121   125   172   183   229   234   270   318   355   363   420   472
# Jun     135   149   178   218   243   264   315   374   422   435   472   535
# Jul     148   170   199   230   264   302   364   413   465   491   548   622
# Aug     148   170   199   242   272   293   347   405   467   505   559   606
# Sep     136   158   184   209   237   259   312   355   404   404   463   508
# Oct     119   133   162   191   211   229   274   306   347   359   407   461
# Nov     104   114   146   172   180   203   237   271   305   310   362   390
# ...

# %%
plt.title('No. of Passengers (1000s)')
sns.heatmap(flights_df);

# %%
plt.title('No. of Passengers (1000s)')
sns.heatmap(flights_df, fmt='d', annot=True, cmap='Blues');

# %% [markdown]
# Images

# %%
from urllib.request import urlretrieve

# %%
image_url = 'https://cdn11.bigcommerce.com/s-jyvxk5hzsq/images/stencil/500x659/products/6029/44001/6751L__24754.1539348498.jpg?c=2'

# %%
file_name = 'chart.jpg'

# %%
urlretrieve(image_url, file_name)
# Out:
# ('chart.jpg', <http.client.HTTPMessage at 0x7e7e1a782c60>)

# %%
from PIL import Image

# %%
img = Image.open('chart.jpg')

# %%
type(img)
# Out:
# PIL.JpegImagePlugin.JpegImageFile

# %%
img_array = np.array(img)

# %%
img_array.shape
img_array
# Out:
# array([[[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [249, 249, 249],
#         [254, 254, 254],
#         [250, 250, 250]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [254, 254, 254],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        ...,
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
# ...

# %%
plt.imshow(img_array);

# %%
plt.grid(False)
plt.title('A data science meme')
plt.axis('off')
plt.imshow(img);

# %%
plt.grid(False)
plt.axis('off')
plt.imshow(img_array[150:400, 0:150]);

# %% [markdown]
# Plotting multiple charts in a grid

# %%
fig, axes = plt.subplots(2,3, figsize= (12,9))
axes[0,0].plot(years, apples, 's-b')
axes[0,0].plot(years, oranges, 'o--r')
axes[0,0].set_xlabel('Year')
axes[0,0].set_ylabel('Yield')
axes[0,0].set_title('Crop Yeilds')
axes[0,0].legend(['Apples', 'Oranges'])

axes[0,1].set_title('Sepal length vs Width')
sns.scatterplot(x=flowers_df.sepal_length, y=flowers_df.sepal_width, hue=flowers_df.species, s=100, ax=axes[0,1])

# axes[0,2].set_title('Distribution of sepal width')
# plt.tight_layout(pad = 2)
# Out:
# <Axes: title={'center': 'Sepal length vs Width'}, xlabel='sepal_length', ylabel='sepal_width'>

# %%
axes
# Out:
# array([[<Axes: >, <Axes: >, <Axes: >],
#        [<Axes: >, <Axes: >, <Axes: >]], dtype=object)

# %%
axes.shape
# Out:
# (2, 3)

# %%
axes[0,0]
# Out:
# <Axes: >

# %%
fig, axes = plt.subplots(2,3, figsize= (16,9))

#Use the axes for plotting
axes[0,0].plot(years, apples, 's-b')
axes[0,0].plot(years, oranges, 'o--r')
axes[0,0].set_xlabel('Year')
axes[0,0].set_ylabel('Yield (tons per hectre)')
axes[0,0].set_title('Crop Yeilds')
axes[0,0].legend(['Apples', 'Oranges'])


#Pass the axes into seaborn
axes[0,1].set_title('Sepal length vs Width')
sns.scatterplot(x=flowers_df.sepal_length, y=flowers_df.sepal_width, hue=flowers_df.species, s=100, ax=axes[0,1])

#Use the axes for plotting
axes[0,2].set_title('Distribution of sepal width')
axes[0,2].hist([setosa_df.sepal_width, versicolor_df.sepal_width, virginica_df.sepal_width], bins=np.arange(2,5, 0.25), stacked=True)
axes[0,2].legend(['setosa', 'versicolor', 'virginica'])

#Pass the axes into seaborn
axes[1,0].set_title('Restaurant Bills')
sns.barplot(x='day', y='total_bill', data=tips_df, hue='sex', ax=axes[1,0]);

#Pass the axes into seaborn
axes[1,1].set_title('Flight Traffic')
sns.heatmap(flights_df, cmap='Blues', ax=axes[1,1]);

#plot an image using the axes
axes[1,2].set_title('Data science meme')
axes[1,2].imshow(img)
axes[1,2].grid(False)
axes[1,2].set_xticks([])
axes[1,2].set_yticks([])
plt.tight_layout(pad = 2)

# %%
https://github.com/rougier/matplotlib-tutorial    #matplotlib for simple line plots, bar plots and simple histograms
#seaborn for complex tasks

# %%
https://github.com/guipsamora/pandas_exercises
# Out:
#   File "/tmp/ipython-input-1351433340.py", line 1
#     https://github.com/guipsamora/pandas_exercises
#           ^
# SyntaxError: invalid syntax

# %% [markdown]
# Pair plots with seaborn
