# %% [markdown]
# In this assignment we are going to analyze and operate on data from a csv file

# %%
import pandas as pd
from urllib.request import urlretrieve
import os

# %%
url = "https://gist.githubusercontent.com/raun1997/9c319461d47fc2e3c6c883ca6cd84267/raw/5499273bcdbfccc33f755957129002b3d364d4b8/locations.csv"
output_file = "countries.csv"
urlretrieve(url, output_file)
# Out:
# ('countries.csv', <http.client.HTTPMessage at 0x7a4f576429f0>)

# %%
countries_df = pd.read_csv(output_file)

# %%
countries_df
# Out:
#           location continent    population  life_expectancy  \
# 0      Afghanistan      Asia  3.892834e+07            64.83
# 1          Albania    Europe  2.877800e+06            78.57
# 2          Algeria    Africa  4.385104e+07            76.88
# 3          Andorra    Europe  7.726500e+04            83.73
# 4           Angola    Africa  3.286627e+07            61.15
# ..             ...       ...           ...              ...
# 207          Yemen      Asia  2.982597e+07            66.12
# 208         Zambia    Africa  1.838396e+07            63.89
# 209       Zimbabwe    Africa  1.486293e+07            61.49
# 210          World       NaN  7.794799e+09            72.58
# 211  International       NaN           NaN              NaN
#
#      hospital_beds_per_thousand  gdp_per_capita
# 0                         0.500        1803.987
# 1                         2.890       11803.431
# 2                         1.900       13913.839
# 3                           NaN             NaN
# ...

# %%
country_df = countries_df.iloc[:-2]

# %%
country_df.to_csv("countries_new.csv", index=False)

# %%
country_df
# Out:
#            location continent  population  life_expectancy  \
# 0       Afghanistan      Asia  38928341.0            64.83
# 1           Albania    Europe   2877800.0            78.57
# 2           Algeria    Africa  43851043.0            76.88
# 3           Andorra    Europe     77265.0            83.73
# 4            Angola    Africa  32866268.0            61.15
# ..              ...       ...         ...              ...
# 205         Vietnam      Asia  97338583.0            75.40
# 206  Western Sahara    Africa    597330.0            70.26
# 207           Yemen      Asia  29825968.0            66.12
# 208          Zambia    Africa  18383956.0            63.89
# 209        Zimbabwe    Africa  14862927.0            61.49
#
#      hospital_beds_per_thousand  gdp_per_capita
# 0                          0.50        1803.987
# 1                          2.89       11803.431
# 2                          1.90       13913.839
# 3                           NaN             NaN
# ...

# %%
from IPython.display import display
with pd.option_context('display.max_rows', 210):
    display(country_df['location'])
# Out:
# 0                           Afghanistan
# 1                               Albania
# 2                               Algeria
# 3                               Andorra
# 4                                Angola
# 5                              Anguilla
# 6                   Antigua and Barbuda
# 7                             Argentina
# 8                               Armenia
# 9                                 Aruba
# 10                            Australia
# 11                              Austria
# 12                           Azerbaijan
# 13                              Bahamas
# 14                              Bahrain
# 15                           Bangladesh
# 16                             Barbados
# 17                              Belarus
# 18                              Belgium
# 19                               Belize
# 20                                Benin
# 21                              Bermuda
# 22                               Bhutan
# ...

# %%
num_countries = len(country_df)
print(f'There are {num_countries} in the dataset.')
# Out:
# There are 210 in the dataset.

# %%
country_df.shape
# Out:
# (210, 6)

# %%
num_countries = country_df.shape[0]
num_countries
# Out:
# 210

# %%
continents = country_df.continent.unique()
print(f'There are {continents} continents in the dataset')
# Out:
# There are ['Asia' 'Europe' 'Africa' 'North America' 'South America' 'Oceania'] continents in the dataset

# %%
import math
total_population = country_df.population.sum()
print(f'The total population is {math.ceil(total_population)}')
# Out:
# The total population is 7757980095

# %% [markdown]
# Q. What is the overall life expectancy around the world?
# *hint: You'll need to take a weighted average of life expectancy using populations as weights*

# %%
weighted_average = (country_df.population * country_df.life_expectancy).sum() / country_df.population.sum()
print(f'The overall life expectancy around the world is {round(weighted_average,2)}')
# Out:
# The overall life expectancy around the world is 72.72

# %% [markdown]
# Q. Create a data frame containing 10 countries with the highest population.
#
# Hint: chain the sort_values and head methods

# %%
# pd.options.display.float_format = '{:.2f}'.format
# pd.set_option('display.max_columns', None)

countries_max_pop = country_df.sort_values('population', ascending=False).head(10)
print(f'The top 10 countries with the highest population is')   #Print a value in f foemat by do not print a table in f string since a DataFrame inside an f-string ({countries_max_pop}), pandas prints it in its repr() form
countries_max_pop       #misaligned columns
# Out:
# The top 10 countries with the highest population is
#           location      continent    population  life_expectancy  \
# 41           China           Asia  1.439324e+09            76.91
# 90           India           Asia  1.380004e+09            69.66
# 199  United States  North America  3.310026e+08            78.86
# 91       Indonesia           Asia  2.735236e+08            71.72
# 145       Pakistan           Asia  2.208923e+08            67.27
# 27          Brazil  South America  2.125594e+08            75.88
# 141        Nigeria         Africa  2.061396e+08            54.69
# 15      Bangladesh           Asia  1.646894e+08            72.59
# 157         Russia         Europe  1.459345e+08            72.58
# 125         Mexico  North America  1.289328e+08            75.05
#
#      hospital_beds_per_thousand  gdp_per_capita
# 41                         4.34       15308.712
# 90                         0.53        6426.674
# 199                        2.77       54225.446
# ...

# %% [markdown]
# Q. Add a new column in country_df to record the overall gdp per country (product of population and per capita gdp)

# %%
country_df.loc[:, 'gdp'] = country_df.population * country_df.gdp_per_capita
country_df
# Out:
# /tmp/ipython-input-548079481.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   country_df.loc[:, 'gdp'] = country_df.population * country_df.gdp_per_capita
#            location continent  population  life_expectancy  \
# 0       Afghanistan      Asia  38928341.0            64.83
# 1           Albania    Europe   2877800.0            78.57
# 2           Algeria    Africa  43851043.0            76.88
# 3           Andorra    Europe     77265.0            83.73
# 4            Angola    Africa  32866268.0            61.15
# ..              ...       ...         ...              ...
# 205         Vietnam      Asia  97338583.0            75.40
# 206  Western Sahara    Africa    597330.0            70.26
# ...

# %% [markdown]
# Q. Creata a dataframe containing 10 countries with lowest GDP per Capita among the countries with population greater than 100 million

# %%
big_countries = country_df[country_df['population'] > 100_000_000]
big_countries
# Out:
#           location      continent    population  life_expectancy  \
# 15      Bangladesh           Asia  1.646894e+08            72.59
# 27          Brazil  South America  2.125594e+08            75.88
# 41           China           Asia  1.439324e+09            76.91
# 58           Egypt         Africa  1.023344e+08            71.99
# 63        Ethiopia         Africa  1.149636e+08            66.60
# 90           India           Asia  1.380004e+09            69.66
# 91       Indonesia           Asia  2.735236e+08            71.72
# 99           Japan           Asia  1.264765e+08            84.63
# 125         Mexico  North America  1.289328e+08            75.05
# 141        Nigeria         Africa  2.061396e+08            54.69
# 145       Pakistan           Asia  2.208923e+08            67.27
# 151    Philippines           Asia  1.095811e+08            71.23
# 157         Russia         Europe  1.459345e+08            72.58
# ...

# %%
lowest_gdp_per_capita = big_countries.sort_values('gdp_per_capita', ascending=True).head(10)
lowest_gdp_per_capita
# Out:
#         location      continent    population  life_expectancy  \
# 63      Ethiopia         Africa  1.149636e+08            66.60
# 15    Bangladesh           Asia  1.646894e+08            72.59
# 145     Pakistan           Asia  2.208923e+08            67.27
# 141      Nigeria         Africa  2.061396e+08            54.69
# 90         India           Asia  1.380004e+09            69.66
# 151  Philippines           Asia  1.095811e+08            71.23
# 58         Egypt         Africa  1.023344e+08            71.99
# 91     Indonesia           Asia  2.735236e+08            71.72
# 27        Brazil  South America  2.125594e+08            75.88
# 41         China           Asia  1.439324e+09            76.91
#
#      hospital_beds_per_thousand  gdp_per_capita           gdp
# 63                         0.30        1729.927  1.988786e+11
# 15                         0.80        3523.984  5.803628e+11
# 145                        0.60        5034.708  1.112128e+12
# ...

# %% [markdown]
# Q. Create a dataframe that counts the number of countries in each continent

# %%
num_countries = country_df.groupby('continent').size().reset_index(name='country_count')
num_countries
# Out:
#        continent  country_count
# 0         Africa             55
# 1           Asia             47
# 2         Europe             51
# 3  North America             36
# 4        Oceania              8
# 5  South America             13

# %% [markdown]
# Q. Create a dataframe showing the total population of each continent

# %%
continent_population_df = country_df.groupby('continent')['population'].sum().reset_index(name='total_population')
continent_population_df
# Out:
#        continent  total_population
# 0         Africa      1.339424e+09
# 1           Asia      4.607388e+09
# 2         Europe      7.485062e+08
# 3  North America      5.912425e+08
# 4        Oceania      4.095832e+07
# 5  South America      4.304611e+08

# %%
file_path = './covid-countries-only.csv'
covid_data_df = pd.read_csv(file_path)
covid_data_df
# Out:
#            location  total_cases  total_deaths  total_tests
# 0       Afghanistan       235214          7998     994894.0
# 1           Albania       335047          3605    1613870.0
# 2           Algeria       272139          6881     243261.0
# 3           Andorra        48015           159     300307.0
# 4            Angola       107481          1937    1618566.0
# ..              ...          ...           ...          ...
# 205         Vietnam     11624000         43206   85699471.0
# 206  Western Sahara         3760             9          NaN
# 207           Yemen        11945          2159     172937.0
# 208          Zambia       349842          4077    3892742.0
# 209        Zimbabwe       266386          5740    2603470.0
#
# [210 rows x 4 columns]

# %% [markdown]
# Q. Count the number of countries for which the total test data is missing

# %%
total_tests_missing = covid_data_df['total_tests'].isna().sum()
print(f'The data for total tests is missing for {total_tests_missing} countries')
# Out:
# The data for total tests is missing for 7 countries

# %% [markdown]
# Q. Merge country_df and covid_data_df on the location column

# %%
combined_df = pd.merge(left=country_df, right=covid_data_df, on='location')
combined_df
# Out:
#            location continent  population  life_expectancy  \
# 0       Afghanistan      Asia  38928341.0            64.83
# 1           Albania    Europe   2877800.0            78.57
# 2           Algeria    Africa  43851043.0            76.88
# 3           Andorra    Europe     77265.0            83.73
# 4            Angola    Africa  32866268.0            61.15
# ..              ...       ...         ...              ...
# 204         Vietnam      Asia  97338583.0            75.40
# 205  Western Sahara    Africa    597330.0            70.26
# 206           Yemen      Asia  29825968.0            66.12
# 207          Zambia    Africa  18383956.0            63.89
# 208        Zimbabwe    Africa  14862927.0            61.49
#
#      hospital_beds_per_thousand  gdp_per_capita           gdp  total_cases  \
# 0                          0.50        1803.987  7.022622e+10       235214
# 1                          2.89       11803.431  3.396791e+10       335047
# ...

# %%
merged_df = pd.merge(country_df, covid_data_df, on='location', how="inner")
merged_df
# Out:
#            location continent  population  life_expectancy  \
# 0       Afghanistan      Asia  38928341.0            64.83
# 1           Albania    Europe   2877800.0            78.57
# 2           Algeria    Africa  43851043.0            76.88
# 3           Andorra    Europe     77265.0            83.73
# 4            Angola    Africa  32866268.0            61.15
# ..              ...       ...         ...              ...
# 204         Vietnam      Asia  97338583.0            75.40
# 205  Western Sahara    Africa    597330.0            70.26
# 206           Yemen      Asia  29825968.0            66.12
# 207          Zambia    Africa  18383956.0            63.89
# 208        Zimbabwe    Africa  14862927.0            61.49
#
#      hospital_beds_per_thousand  gdp_per_capita           gdp  total_cases  \
# 0                          0.50        1803.987  7.022622e+10       235214
# 1                          2.89       11803.431  3.396791e+10       335047
# ...

# %% [markdown]
# Q. Add columns tests_per_million, cases_per_million, deaths_per_million into combined_df

# %%
combined_df['tests_per_million'] = combined_df['total_tests'] *1e6 / combined_df['population']
combined_df['cases_per_million'] = combined_df['total_cases'] * 1e6 / combined_df['population']
combined_df['deaths_per_million'] = combined_df['total_deaths'] * 1e6 / combined_df['population']
combined_df
# Out:
#            location continent  population  life_expectancy  \
# 0       Afghanistan      Asia  38928341.0            64.83
# 1           Albania    Europe   2877800.0            78.57
# 2           Algeria    Africa  43851043.0            76.88
# 3           Andorra    Europe     77265.0            83.73
# 4            Angola    Africa  32866268.0            61.15
# ..              ...       ...         ...              ...
# 204         Vietnam      Asia  97338583.0            75.40
# 205  Western Sahara    Africa    597330.0            70.26
# 206           Yemen      Asia  29825968.0            66.12
# 207          Zambia    Africa  18383956.0            63.89
# 208        Zimbabwe    Africa  14862927.0            61.49
#
#      hospital_beds_per_thousand  gdp_per_capita           gdp  total_cases  \
# 0                          0.50        1803.987  7.022622e+10       235214
# 1                          2.89       11803.431  3.396791e+10       335047
# ...

# %% [markdown]
# Q. Create a dataframe with 10 countries that have the highest number of tests per million

# %%
highest_tests_df = combined_df.sort_values(by='tests_per_million', ascending=False).head(10)
highest_tests_df
# Out:
#                  location      continent  population  life_expectancy  \
# 53                Denmark         Europe   5792203.0            80.90
# 11                Austria         Europe   9006400.0            81.54
# 196  United Arab Emirates           Asia   9890400.0            77.97
# 21                Bermuda  North America     62273.0            82.59
# 74              Gibraltar         Europe     33691.0            79.93
# 86              Hong Kong           Asia   7496988.0            84.86
# 114            Luxembourg         Europe    625976.0            82.25
# 50                 Cyprus         Europe    875899.0            80.98
# 75                 Greece         Europe  10423056.0            82.24
# 14                Bahrain           Asia   1701583.0            77.29
#
#      hospital_beds_per_thousand  gdp_per_capita           gdp  total_cases  \
# 53                         2.50       46682.515  2.703946e+11      3435679
# ...

# %% [markdown]
# Q. Create a dataframe with 10 countries that have the highest number of positive cases per million

# %%
highest_cases_df = combined_df.sort_values(by='cases_per_million', ascending=False).head(10)
highest_cases_df
# Out:
#         location continent  population  life_expectancy  \
# 50        Cyprus    Europe    875899.0            80.98
# 29        Brunei      Asia    437483.0            75.86
# 161   San Marino    Europe     33938.0            84.97
# 11       Austria    Europe   9006400.0            81.54
# 174  South Korea      Asia  51269183.0            83.03
# 99        Jersey    Europe    101073.0              NaN
# 171     Slovenia    Europe   2078932.0            81.32
# 114   Luxembourg    Europe    625976.0            82.25
# 3        Andorra    Europe     77265.0            83.73
# 88       Iceland    Europe    341250.0            82.99
#
#      hospital_beds_per_thousand  gdp_per_capita           gdp  total_cases  \
# 50                         3.40       32415.132  2.839238e+10       696410
# 29                         2.70       71809.251  3.141533e+10       347723
# 161                        3.80       56861.470  1.929765e+09        25292
# ...

# %% [markdown]
# Q. Create a dataframe with 10 countries that have the highest number of death cases per million

# %%
highest_deaths_df = combined_df.sort_values(by='deaths_per_million', ascending=False).head(10)
highest_deaths_df
# Out:
#                    location      continent  population  life_expectancy  \
# 149                    Peru  South America  32971846.0            76.74
# 30                 Bulgaria         Europe   6948445.0            75.05
# 87                  Hungary         Europe   9660350.0            76.88
# 25   Bosnia and Herzegovina         Europe   3280815.0            77.40
# 171                Slovenia         Europe   2078932.0            81.32
# 115               Macedonia         Europe   2083380.0            75.80
# 47                  Croatia         Europe   4105268.0            78.49
# 71                  Georgia           Asia   3989175.0            73.77
# 128              Montenegro         Europe    628062.0            76.88
# 51           Czech Republic         Europe  10708982.0            79.38
#
#      hospital_beds_per_thousand  gdp_per_capita           gdp  total_cases  \
# 149                       1.600       12236.706  4.034668e+11      4526977
# ...

# %% [markdown]
# Q. Count the number of countries that feature in both the lists of 'highest number of tests per million' and 'highest number of cases per million'

# %%
set_tests = set(highest_tests_df['location'].tolist())
set_tests
# Out:
# {'Austria',
#  'Bahrain',
#  'Bermuda',
#  'Cyprus',
#  'Denmark',
#  'Gibraltar',
#  'Greece',
#  'Hong Kong',
#  'Luxembourg',
#  'United Arab Emirates'}

# %%
set_cases = set(highest_cases_df['location'].tolist())
set_cases
# Out:
# {'Andorra',
#  'Austria',
#  'Brunei',
#  'Cyprus',
#  'Iceland',
#  'Jersey',
#  'Luxembourg',
#  'San Marino',
#  'Slovenia',
#  'South Korea'}

# %%
common_countries = set_tests.intersection(set_cases)
common_countries
# Out:
# {'Austria', 'Cyprus', 'Luxembourg'}

# %%
count_common_countries = len(common_countries)
print(f"The number of countries that feature in both lists is: {count_common_countries}")
# Out:
# The number of countries that feature in both lists is: 3

# %% [markdown]
#   Q. Count the number of countries that feature in both the lists '20 countries with lowest GDP per capita' and '20 countries with lowest number of hospital beds per thousand population'. Only consider countries with a population higher than 10 million while creating the list

# %%
countries_with_hundred_million_population = combined_df[combined_df['population'] > 10000000]
countries_with_hundred_million_population
# Out:
#         location      continent  population  life_expectancy  \
# 0    Afghanistan           Asia  38928341.0            64.83
# 2        Algeria         Africa  43851043.0            76.88
# 4         Angola         Africa  32866268.0            61.15
# 7      Argentina  South America  45195777.0            76.67
# 10     Australia        Oceania  25499881.0            83.44
# ..           ...            ...         ...              ...
# 203    Venezuela  South America  28435943.0            72.06
# 204      Vietnam           Asia  97338583.0            75.40
# 206        Yemen           Asia  29825968.0            66.12
# 207       Zambia         Africa  18383956.0            63.89
# 208     Zimbabwe         Africa  14862927.0            61.49
#
#      hospital_beds_per_thousand  gdp_per_capita           gdp  total_cases  \
# 0                          0.50        1803.987  7.022622e+10       235214
# 2                          1.90       13913.839  6.101364e+11       272139
# ...

# %%
lowest_gdp_countries = countries_with_hundred_million_population.sort_values(by='gdp_per_capita', ascending=True).head(20)['location'].tolist()
lowest_gdp_countries
# Out:
# ['Burundi',
#  'Democratic Republic of Congo',
#  'Niger',
#  'Malawi',
#  'Mozambique',
#  'Madagascar',
#  'Yemen',
#  'South Sudan',
#  'Haiti',
#  'Uganda',
#  'Burkina Faso',
#  'Ethiopia',
#  'Chad',
#  'Afghanistan',
#  'Rwanda',
#  'Zimbabwe',
#  'Guinea',
#  'Mali',
#  'Benin',
#  'Nepal']

# %%
lowest_beds_countries = countries_with_hundred_million_population.sort_values(by='hospital_beds_per_thousand', ascending=True).head(20)['location'].tolist()
lowest_beds_countries
# Out:
# ['Mali',
#  'Madagascar',
#  'Guinea',
#  'Ethiopia',
#  'Nepal',
#  'Niger',
#  'Burkina Faso',
#  'Afghanistan',
#  'Benin',
#  'Uganda',
#  'India',
#  'Guatemala',
#  'Pakistan',
#  'Mozambique',
#  'Tanzania',
#  'Haiti',
#  'Yemen',
#  'Bangladesh',
#  'Burundi',
#  'Venezuela']

# %%
same_countries = set(lowest_gdp_countries).intersection(set(lowest_beds_countries))
same_countries
# Out:
# {'Afghanistan',
#  'Benin',
#  'Burkina Faso',
#  'Burundi',
#  'Ethiopia',
#  'Guinea',
#  'Haiti',
#  'Madagascar',
#  'Mali',
#  'Mozambique',
#  'Nepal',
#  'Niger',
#  'Uganda',
#  'Yemen'}

# %%
count_same_countries = len(same_countries)
print(f"The number of countries that feature in both lists is: {count_same_countries}")
# Out:
# The number of countries that feature in both lists is: 14
